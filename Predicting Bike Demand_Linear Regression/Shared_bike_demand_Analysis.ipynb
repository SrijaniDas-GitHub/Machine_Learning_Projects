# %% [markdown]
# ### Approach
#
# In order to predict shared bike demand following approach has been taken.
#
# 1. Import modules, Read dataset
#
# 2. Working with Categorical Data
#  - Encoding
#  - Univariate and Bivariate Analysis, Visualization
#  - Dropping columns (if applicable)
#
# 3. Working with Numeric Data
#  - Checking statistical summary
#  - Univariate and Bivariate Analysis, Visualization
#  - Outlier Detection
#  - dropping columns (if applicable)
#
# 4. Split train-test and Scaling
#
# 5. Feature selection and Building Model
#   - Extract top n features with RFE
#   - Improvise the model further inspecting adjusted R-squared, VIF and p-vales
#   - Build final model
#   - validate linear regression assumptions, residuals
#
# 6. Predicting target variable using final model
#
# 7. Model evaluation
#   - R2 square
#   - RMSE/MSE

# %% [markdown]
# ### Importing Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

plt.style.use('ggplot')

# %% [markdown]
# ### Reading the dataset

# %%
df = pd.read_csv("day.csv")
df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        1           1
# 1        2  02-01-2018       1   0     1        0        2           1
# 2        3  03-01-2018       1   0     1        0        3           1
# 3        4  04-01-2018       1   0     1        0        4           1
# 4        5  05-01-2018       1   0     1        0        5           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %% [markdown]
# **Comment**
#
# - The dataset does not have any missing value, has 730 rows and 16 columns.
# - 'instant' is a unique identifier column, hence setting this as index
# - Year, Month and Date can be extracted from 'dteday'. After that 'dteday', 'mnth', 'yr' columns can be dropped.
# - Categorical features like 'season', 'weathersit' and 'weekday' have numeric value like 1,2,3...
#   We will encode them for better readability and suitable for regression model.
# - Categorical features ('holiday', 'workingday') are already labeled as 0 and 1 - do not need further encoding
# - Numeric columns are : temp, atemp, hum, windspeed, casual, registered, cnt - will be analyzed separately

# %%
df.set_index('instant', inplace=True)
df.head()
# Out:
#              dteday  season  yr  mnth  holiday  weekday  workingday  \
# instant
# 1        01-01-2018       1   0     1        0        1           1
# 2        02-01-2018       1   0     1        0        2           1
# 3        03-01-2018       1   0     1        0        3           1
# 4        04-01-2018       1   0     1        0        4           1
# 5        05-01-2018       1   0     1        0        5           1
#
#          weathersit       temp     atemp      hum  windspeed  casual  \
# instant
# 1                 2  14.110847  18.18125  80.5833  10.749882     331
# 2                 2  14.902598  17.68695  69.6087  16.652113     131
# 3                 1   8.050924   9.47025  43.7273  16.636703     120
# 4                 1   8.200000  10.60610  59.0435  10.739832     108
# 5                 1   9.305237  11.46350  43.6957  12.522300      82
#
#          registered   cnt
# instant
# 1               654   985
# 2               670   801
# 3              1229  1349
# 4              1454  1562
# 5              1518  1600

# %%
df["date"] = pd.DatetimeIndex(df["dteday"]).day
df["month"] = pd.DatetimeIndex(df["dteday"]).month_name()
df["year"] = pd.DatetimeIndex(df["dteday"]).year

# dropping the redundant columns
df.drop(["dteday","mnth"], axis=1, inplace=True)

# checking the new dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 730 entries, 1 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    int64
#  1   yr          730 non-null    int64
#  2   holiday     730 non-null    int64
#  3   weekday     730 non-null    int64
#  4   workingday  730 non-null    int64
#  5   weathersit  730 non-null    int64
#  6   temp        730 non-null    float64
#  7   atemp       730 non-null    float64
#  8   hum         730 non-null    float64
#  9   windspeed   730 non-null    float64
#  10  casual      730 non-null    int64
#  11  registered  730 non-null    int64
#  12  cnt         730 non-null    int64
#  13  date        730 non-null    int64
#  14  month       730 non-null    object
#  15  year        730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 97.0+ KB

# %%
df.groupby("weekday").sum()["workingday"]
# Out:
# weekday
# 0      0
# 1    105
# 2    100
# 3     93
# 4    103
# 5    103
# 6      0
# Name: workingday, dtype: int64

# %% [markdown]
# **Comment:**
# - This means Sunday is encoded as 0 and Saturday is encoded as 6

# %%
# season, weathersit, weekday

name_dict = {"season" : {1:"spring", 2:"summer", 3:"fall", 4:"winter"}, 
             "weathersit" : {1: "Clear/Partly Cloudy", 2: "Mist and Cloudy", 3: "Light Snow/Rain", 4: "Heavy Snow/Rain"},
             "weekday" : {0: "Sunday", 1:"Monday", 2:"Tuesday", 3:"Wednesday", 4:"Thursday", 5:"Friday", 6:"Saturday"}}

for column in name_dict.keys():
    df[column] = df[column].apply(lambda x : name_dict[column][x])

df.head()
# Out:
#          season  yr  holiday    weekday  workingday           weathersit  \
# instant
# 1        spring   0        0     Monday           1      Mist and Cloudy
# 2        spring   0        0    Tuesday           1      Mist and Cloudy
# 3        spring   0        0  Wednesday           1  Clear/Partly Cloudy
# 4        spring   0        0   Thursday           1  Clear/Partly Cloudy
# 5        spring   0        0     Friday           1  Clear/Partly Cloudy
#
#               temp     atemp      hum  windspeed  casual  registered   cnt  \
# instant
# 1        14.110847  18.18125  80.5833  10.749882     331         654   985
# 2        14.902598  17.68695  69.6087  16.652113     131         670   801
# 3         8.050924   9.47025  43.7273  16.636703     120        1229  1349
# 4         8.200000  10.60610  59.0435  10.739832     108        1454  1562
# 5         9.305237  11.46350  43.6957  12.522300      82        1518  1600
#
#          date     month  year
# instant
# 1           1   January  2018
# 2           1  February  2018
# 3           1     March  2018
# 4           1     April  2018
# 5           1       May  2018

# %% [markdown]
# ### Visualizing Categorical Data

# %%
fig = plt.figure(figsize=(12,6))

ax1 = fig.add_subplot(1, 3, 1, title="Shared Bike Demand based on Season")
ax2 = fig.add_subplot(1, 3, 2, title="Shared Bike Demand based on Weather")

df.groupby('season').sum().sort_values('cnt', ascending=False)[['cnt']].plot.bar(ax=ax1)
df.groupby('weathersit').sum().sort_values('cnt', ascending=False)[['cnt']].plot.bar(ax=ax2)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Comment:**
# - People are most likely to rent shared bikes in fall and least likely to rent shared bikes in spring
# - Highest demand of shared bikes is seen in Clear/Partly Cloudy weather
# - Light Snow/Rain results in very low bike demand and there is no bike demand in Heavy Snow/Rain

# %%
fig = plt.figure(figsize=(20,10))

ax1 = fig.add_subplot(2, 2, 1, title="Bike Demand based on Dates")
ax2 = fig.add_subplot(2, 2, 2, title="Bike Demand based on Years")
ax3 = fig.add_subplot(2, 2, 3, title="Bike Demand based on Months")
ax4 = fig.add_subplot(2, 2, 4, title="Bike Demand based on Week")

sns.boxplot(df['date'], df['cnt'], ax=ax1)
sns.boxplot(df['year'], df['cnt'], ax=ax2)
sns.boxplot(df['month'], df['cnt'], ax=ax3)
sns.boxplot(df['weekday'], df['cnt'], ax=ax4)

plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Comment:**
# - Dates between 5-8 have shown comparatively higher demand. This might be because of other underlying factors for e.g. holidays.
# - Demand of share bikes increased a lot in 2019 from previous year.
# - November, December, January, February months have comparative less demands than other months.
# - Highest number of bike rent in a day is higher on Satuday, Sunday than weekdays

# %%
fig = plt.figure(figsize=(12,6))

ax1 = fig.add_subplot(1, 2, 1, title="Bike Demand on Holidays")
ax2 = fig.add_subplot(1, 2, 2, title="Bike Demand on Working days")

sns.boxplot(df['holiday'], df['cnt'], ax=ax1)
sns.boxplot(df['workingday'], df['cnt'], ax=ax2)

plt.show()

# %% [markdown]
# **Comment**
# - Bike demand is very similar whether its working day or not, working day has slightly less demand
# - The lowest number of bike rents is higher on holidays than that of non-holidays
# - The highest number of bike rents is higher on non-holidays than that of holidays

# %%
df.groupby('month').sum().sort_values('cnt', ascending=False)[['cnt']].plot.bar()
plt.title("Monthly trend of Bike demand")
plt.show()

# %% [markdown]
# ### Encoding the categorical Variables

# %% [markdown]
# Month shows very strong trend for bike demands.
# Dividing the months into 4 groups based of bike demand trend seen above.
#
# - group1 [July, August, Sepetember] column name : jul_aug_sep (Highest bike demand)
# - group2 [May, Jun, Oct] column name : may_jun_oct
# - group3 [March, April, November] column name: mar_apr_nov
# - group4 [December, February, January] (Lowest bike demand)
# For the last group, no columns will be required as 0 in the first 3 groups would signify it.

# %%
df["jul_aug_sep"] = df["month"].apply(lambda month : 1 if month in ["July","August","September"] else 0)
df["may_jun_oct"] = df["month"].apply(lambda month : 1 if month in ["May","June","October"] else 0)
df["mar_apr_nov"] = df["month"].apply(lambda month : 1 if month in ["March","April","November"] else 0)

# %%
# dropping 'month', 'year' columns as it is redundant now
df.drop(['month'], axis=1, inplace=True)
df.drop(['year'], axis=1, inplace=True)

# %%
def add_dummies(df, feature):
    dummy_df = pd.get_dummies(df[feature], drop_first='True')
    df.drop(feature, axis=1, inplace=True)
    print(df.columns)
    return pd.concat([df,dummy_df], axis=1)

df = add_dummies(df,'season')
df = add_dummies(df,'weekday')
df = add_dummies(df,'weathersit')
# Out:
# Index(['yr', 'holiday', 'weekday', 'workingday', 'weathersit', 'temp', 'atemp',
#        'hum', 'windspeed', 'casual', 'registered', 'cnt', 'date',
#        'jul_aug_sep', 'may_jun_oct', 'mar_apr_nov'],
#       dtype='object')
# Index(['yr', 'holiday', 'workingday', 'weathersit', 'temp', 'atemp', 'hum',
#        'windspeed', 'casual', 'registered', 'cnt', 'date', 'jul_aug_sep',
#        'may_jun_oct', 'mar_apr_nov', 'spring', 'summer', 'winter'],
#       dtype='object')
# Index(['yr', 'holiday', 'workingday', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt', 'date', 'jul_aug_sep', 'may_jun_oct',
#        'mar_apr_nov', 'spring', 'summer', 'winter', 'Monday', 'Saturday',
#        'Sunday', 'Thursday', 'Tuesday', 'Wednesday'],
#       dtype='object')

# %% [markdown]
# ### Visualizing Numeric Data

# %%
df_num_var = df[["temp", "atemp", "hum", "windspeed", "casual", "registered", "cnt"]]

# %%
plt.figure()
sns.pairplot(df_num_var)
plt.show()

# %%
plt.figure()
sns.heatmap(df_num_var.corr(), annot=True)
plt.show()

# %% [markdown]
# **Comment**
# - temp and atemp have very high linear relationship (as seen in the pairplot), their correlation coefficient as high as 0.99
# - cnt, registered columns look linearly related too

# %%
df[~(df['casual'] + df['registered'] == df['cnt'])]
# Out:
# Empty DataFrame
# Columns: [yr, holiday, workingday, temp, atemp, hum, windspeed, casual, registered, cnt, date, jul_aug_sep, may_jun_oct, mar_apr_nov, spring, summer, winter, Monday, Saturday, Sunday, Thursday, Tuesday, Wednesday, Light Snow/Rain, Mist and Cloudy]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# **Comment**
# - 'cnt' is our target variable and we see that casual + registered = cnt
# - Hence, casual and registered are dependant variables and can be dropped

# %%
fig=plt.subplots(figsize=(10, 10))

for i, j in enumerate(["temp", "atemp", "hum", "windspeed", "casual", "registered", "cnt"]):
    plt.subplot(6, 3, i+1)
    plt.subplots_adjust(hspace = 1.0)
    sns.distplot(df[j])
    plt.tight_layout()

# %% [markdown]
# **Comment**
# - temp and atemp have similar distribution
# - Humidity is most likely to be between 50-75 units
# - Windspeed is most commonly seen between 8-12 units
# - registered and cnt have similar distribution, as majority of the bikes are rented by registered customers

# %% [markdown]
# ### Outlier Detection for Numeric Variables

# %%
fig=plt.subplots(figsize=(10, 10))

for i, j in enumerate(["temp", "atemp", "hum", "windspeed", "casual", "registered", "cnt"]):
    plt.subplot(6, 3, i+1)
    plt.subplots_adjust(hspace = 1.0)
    sns.boxplot(df[j])
    plt.tight_layout()

# %% [markdown]
# **Comment**
# - For 'windspeed' and 'casual', we can see some outliers.
# - 'windspeed' is a predictor and 'casual' is directly related to 'cnt' as casual + registered = cnt
# - We will consider 99 percentile for both of this

# %%
df = df[~((df.windspeed > np.nanpercentile(df.windspeed, 99)) | (df.casual > np.nanpercentile(df['casual'], 99)))]
print(df.shape)
# Out:
# (714, 25)

# %% [markdown]
# ### Splitting the data and Scaling

# %%
# Since cnt = casual + register, casual and register cannot be counted as predictors to prevent data leakage
X = df.drop(['cnt', 'casual', 'registered'], axis=1)
y = df[['cnt']]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
num_vars = ['temp', 'atemp', 'hum', 'windspeed']
X[num_vars].describe()
# Out:
#              temp       atemp         hum   windspeed
# count  714.000000  714.000000  714.000000  714.000000
# mean    20.331718   23.744378   63.058290   12.589957
# std      7.531352    8.165370   14.075154    4.930469
# min      2.424346    3.953480    0.000000    1.500244
# 25%     13.777701   16.869600   52.458300    9.011098
# 50%     20.465826   24.368225   63.000000   12.041441
# 75%     26.914798   30.547988   73.218750   15.495073
# max     35.328347   42.044800   97.250000   27.292182

# %% [markdown]
# We will scale the only numeric features, excluding categorical features encoded with 0 and 1

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train[num_vars] = scaler.fit_transform(X_train[num_vars])
X_test[num_vars] = scaler.transform(X_test[num_vars])

# %% [markdown]
# # Building Model

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calculate_vif(X_train):
    vif_df = pd.DataFrame()
    vif_df['Features'] = X_train.columns
    vif_df['Variance Inflation Factor'] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
    vif_df['Variance Inflation Factor'] = round(vif_df['Variance Inflation Factor'], 2)
    vif_df = vif_df.sort_values(by = 'Variance Inflation Factor', ascending = False)
    print(vif_df)

# %%
# Regressor 1 : This is the model including all features

X_train_lm = sm.add_constant(X_train)
regressor1 = sm.OLS(y_train, X_train_lm).fit()
print(regressor1.summary())
print("=======================================================================================================")
calculate_vif(X_train)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.827
# Model:                            OLS   Adj. R-squared:                  0.819
# Method:                 Least Squares   F-statistic:                     103.6
# Date:                Mon, 28 Dec 2020   Prob (F-statistic):          1.05e-165
# Time:                        19:33:43   Log-Likelihood:                -4039.9
# No. Observations:                 499   AIC:                             8126.
# Df Residuals:                     476   BIC:                             8223.
# Df Model:                          22
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            3744.3907    673.061      5.563      0.000    2421.853    5066.929
# yr               1976.5341     74.432     26.555      0.000    1830.278    2122.790
# holiday         -1174.8189    484.414     -2.425      0.016   -2126.674    -222.964
# workingday       -730.2436    555.739     -1.314      0.189   -1822.249     361.761
# temp             3807.5087   1205.391      3.159      0.002    1438.964    6176.054
# atemp            -209.8833   1232.231     -0.170      0.865   -2631.167    2211.401
# hum             -1244.5504    351.392     -3.542      0.000   -1935.021    -554.080
# windspeed        -993.3962    209.347     -4.745      0.000   -1404.755    -582.037
# date               -3.7936      4.337     -0.875      0.382     -12.316       4.728
# jul_aug_sep       170.6118    122.342      1.395      0.164     -69.786     411.010
# may_jun_oct       257.5058    115.395      2.232      0.026      30.759     484.253
# mar_apr_nov       253.1175    114.652      2.208      0.028      27.831     478.404
# spring           -918.0934    200.255     -4.585      0.000   -1311.586    -524.601
# summer            265.7798    132.757      2.002      0.046       4.918     526.642
# winter            653.4883    158.712      4.117      0.000     341.625     965.352
# Monday           -346.2690    139.651     -2.480      0.014    -620.678     -71.860
# Saturday         -793.2194    567.761     -1.397      0.163   -1908.848     322.409
# Sunday           -812.2972    562.824     -1.443      0.150   -1918.225     293.630
# Thursday          -31.6192    139.709     -0.226      0.821    -306.142     242.904
# Tuesday          -315.1987    140.385     -2.245      0.025    -591.049     -39.348
# Wednesday        -163.5336    143.327     -1.141      0.254    -445.165     118.098
# Light Snow/Rain -2023.3418    240.517     -8.412      0.000   -2495.949   -1550.735
# Mist and Cloudy  -465.0481     99.440     -4.677      0.000    -660.445    -269.652
# ==============================================================================
# Omnibus:                       72.991   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              143.058
# Skew:                          -0.831   Prob(JB):                     8.62e-32
# Kurtosis:                       5.030   Cond. No.                         834.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# =======================================================================================================
#            Features  Variance Inflation Factor
# 3              temp                     384.18
# 4             atemp                     367.72
# 2        workingday                      47.05
# 5               hum                      37.98
# 15         Saturday                      11.10
# 16           Sunday                      10.20
# 6         windspeed                       7.28
# 11           spring                       6.16
# 7              date                       4.42
# 13           winter                       4.33
# 12           summer                       3.18
# 8       jul_aug_sep                       2.80
# 9       may_jun_oct                       2.68
# 21  Mist and Cloudy                       2.54
# 10      mar_apr_nov                       2.37
# 1           holiday                       2.14
# 18          Tuesday                       2.11
# 14           Monday                       2.10
# 17         Thursday                       2.10
# 19        Wednesday                       2.10
# 0                yr                       2.10
# 20  Light Snow/Rain                       1.39

# %% [markdown]
# **Comment:**
#
# - High f-statistic value confirm the linear regressor model is a significant one.

# %%
# Importing RFE and LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

def top_n_features(n):
    top_n_feat = []
    
    lm = LinearRegression()
    lm.fit(X_train_lm, y_train)
    rfe = RFE(lm, n)
    rfe = rfe.fit(X_train_lm, y_train)
    
    print("Top %d features selected by RFE" %n)
    ranking = list(zip(X_train_lm.columns,rfe.support_,rfe.ranking_))
    
    for i in ranking:
        if i[1]:
            top_n_feat.append(i[0])
    print(top_n_feat)
    return top_n_feat

# %%
top_10_feat = top_n_features(10)
top_12_feat = top_n_features(12)
top_15_feat = top_n_features(15)
# Out:
# Top 10 features selected by RFE
# ['yr', 'holiday', 'workingday', 'temp', 'hum', 'windspeed', 'spring', 'Saturday', 'Sunday', 'Light Snow/Rain']
# Top 12 features selected by RFE
# ['yr', 'holiday', 'workingday', 'temp', 'hum', 'windspeed', 'spring', 'winter', 'Saturday', 'Sunday', 'Light Snow/Rain', 'Mist and Cloudy']
# Top 15 features selected by RFE
# ['yr', 'holiday', 'workingday', 'temp', 'hum', 'windspeed', 'spring', 'summer', 'winter', 'Monday', 'Saturday', 'Sunday', 'Tuesday', 'Light Snow/Rain', 'Mist and Cloudy']

# %% [markdown]
# **Comment:** We would check the adjusted R-squared value of the linear regressor model by taking 10, 12, 15 features respectively

# %%
def build_regressor(X_train,y_train,cols):
    X_train_new = X_train[cols]
    X_train_lm = sm.add_constant(X_train_new)
    regressor = sm.OLS(y_train, X_train_lm).fit()
    print(regressor.summary())
    print("=======================================================================================================")
    calculate_vif(X_train_lm)

# %%
build_regressor(X_train,y_train,top_10_feat)
print("\n\n")
build_regressor(X_train,y_train,top_12_feat)
print("\n\n")
build_regressor(X_train,y_train,top_15_feat)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.805
# Model:                            OLS   Adj. R-squared:                  0.801
# Method:                 Least Squares   F-statistic:                     201.9
# Date:                Mon, 28 Dec 2020   Prob (F-statistic):          2.49e-166
# Time:                        19:33:43   Log-Likelihood:                -4069.6
# No. Observations:                 499   AIC:                             8161.
# Df Residuals:                     488   BIC:                             8208.
# Df Model:                          10
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            4736.7650    658.899      7.189      0.000    3442.135    6031.395
# yr               1959.3560     77.162     25.393      0.000    1807.745    2110.967
# holiday          -930.3557    503.170     -1.849      0.065   -1919.004      58.292
# workingday       -443.9043    575.435     -0.771      0.441   -1574.541     686.732
# temp             2857.2107    218.721     13.063      0.000    2427.460    3286.961
# hum             -2161.4248    288.328     -7.496      0.000   -2727.942   -1594.907
# windspeed       -1196.5499    208.330     -5.744      0.000   -1605.885    -787.215
# spring          -1610.4575    117.874    -13.663      0.000   -1842.060   -1378.855
# Saturday         -395.2669    575.796     -0.686      0.493   -1526.613     736.079
# Sunday           -389.8439    570.463     -0.683      0.495   -1510.710     731.022
# Light Snow/Rain -1631.4379    232.238     -7.025      0.000   -2087.749   -1175.127
# ==============================================================================
# Omnibus:                       56.413   Durbin-Watson:                   2.040
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               91.713
# Skew:                          -0.730   Prob(JB):                     1.22e-20
# Kurtosis:                       4.510   Cond. No.                         54.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# =======================================================================================================
#            Features  Variance Inflation Factor
# 0             const                     298.31
# 3        workingday                      49.40
# 8          Saturday                      30.04
# 9            Sunday                      27.29
# 2           holiday                       4.41
# 7            spring                       1.74
# 4              temp                       1.73
# 5               hum                       1.20
# 6         windspeed                       1.15
# 10  Light Snow/Rain                       1.15
# 1                yr                       1.02
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.818
# Model:                            OLS   Adj. R-squared:                  0.814
# Method:                 Least Squares   F-statistic:                     182.4
# Date:                Mon, 28 Dec 2020   Prob (F-statistic):          2.84e-171
# Time:                        19:33:43   Log-Likelihood:                -4052.4
# No. Observations:                 499   AIC:                             8131.
# Df Residuals:                     486   BIC:                             8186.
# Df Model:                          12
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            3936.0318    655.500      6.005      0.000    2648.067    5223.996
# yr               1983.0505     75.306     26.333      0.000    1835.085    2131.016
# holiday         -1109.0799    488.192     -2.272      0.024   -2068.308    -149.852
# workingday       -614.0141    557.961     -1.100      0.272   -1710.327     482.299
# temp             3268.9402    271.044     12.061      0.000    2736.378    3801.502
# hum             -1225.9761    349.835     -3.504      0.000   -1913.351    -538.601
# windspeed        -934.1384    206.556     -4.522      0.000   -1339.992    -528.285
# spring          -1300.0145    146.135     -8.896      0.000   -1587.149   -1012.880
# winter            400.5296    116.043      3.452      0.001     172.521     628.538
# Saturday         -499.6075    557.732     -0.896      0.371   -1595.470     596.255
# Sunday           -537.1322    552.872     -0.972      0.332   -1623.447     549.183
# Light Snow/Rain -2046.0900    241.430     -8.475      0.000   -2520.465   -1571.715
# Mist and Cloudy  -469.5089     99.729     -4.708      0.000    -665.461    -273.557
# ==============================================================================
# Omnibus:                       76.392   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              149.572
# Skew:                          -0.866   Prob(JB):                     3.32e-33
# Kurtosis:                       5.048   Cond. No.                         56.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# =======================================================================================================
#            Features  Variance Inflation Factor
# 0             const                     315.03
# 3        workingday                      49.55
# 9          Saturday                      30.08
# 10           Sunday                      27.35
# 2           holiday                       4.43
# 7            spring                       2.86
# 4              temp                       2.83
# 5               hum                       1.89
# 8            winter                       1.83
# 12  Mist and Cloudy                       1.64
# 11  Light Snow/Rain                       1.33
# 6         windspeed                       1.20
# 1                yr                       1.04
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.824
# Model:                            OLS   Adj. R-squared:                  0.819
# Method:                 Least Squares   F-statistic:                     150.8
# Date:                Mon, 28 Dec 2020   Prob (F-statistic):          2.94e-171
# Time:                        19:33:43   Log-Likelihood:                -4044.4
# No. Observations:                 499   AIC:                             8121.
# Df Residuals:                     483   BIC:                             8188.
# Df Model:                          15
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            3653.5314    663.818      5.504      0.000    2349.203    4957.860
# yr               1975.6676     74.423     26.546      0.000    1829.434    2121.901
# holiday         -1114.0747    481.903     -2.312      0.021   -2060.961    -167.188
# workingday       -583.5642    551.250     -1.059      0.290   -1666.709     499.581
# temp             3657.1405    311.322     11.747      0.000    3045.427    4268.854
# hum             -1305.1718    346.535     -3.766      0.000   -1986.074    -624.270
# windspeed        -987.3970    205.879     -4.796      0.000   -1391.927    -582.867
# spring           -982.5281    191.694     -5.125      0.000   -1359.186    -605.870
# summer            316.2776    120.742      2.619      0.009      79.034     553.521
# winter            663.4637    151.969      4.366      0.000     364.862     962.065
# Monday           -275.2926    112.051     -2.457      0.014    -495.461     -55.124
# Saturday         -582.7767    551.687     -1.056      0.291   -1666.780     501.227
# Sunday           -606.9841    546.939     -1.110      0.268   -1681.657     467.689
# Tuesday          -253.3735    112.033     -2.262      0.024    -473.506     -33.241
# Light Snow/Rain -1985.2718    239.679     -8.283      0.000   -2456.213   -1514.330
# Mist and Cloudy  -457.2988     98.555     -4.640      0.000    -650.948    -263.650
# ==============================================================================
# Omnibus:                       71.478   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              136.739
# Skew:                          -0.825   Prob(JB):                     2.03e-30
# Kurtosis:                       4.964   Cond. No.                         57.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# =======================================================================================================
#            Features  Variance Inflation Factor
# 0             const                     331.57
# 3        workingday                      49.64
# 11         Saturday                      30.20
# 12           Sunday                      27.47
# 7            spring                       5.05
# 2           holiday                       4.43
# 4              temp                       3.83
# 9            winter                       3.23
# 8            summer                       2.06
# 5               hum                       1.90
# 15  Mist and Cloudy                       1.65
# 14  Light Snow/Rain                       1.34
# 6         windspeed                       1.23
# 10           Monday                       1.17
# 13          Tuesday                       1.17
# 1                yr                       1.04

# %% [markdown]
# **Comment:**
# - With top 15 features given by RFE, the model resulted in adjusted R-squared of 0.819
# - Both top 10 and top 12 features on the other hand produced adjusted R-squared lower than that
# - We will now manually inspect the p-values and VIF for the model built with top 15 features and try to improvise it.

# %%
# Removing Saturday

top_14 = ['yr', 'holiday', 'workingday', 'temp', 'hum', 'windspeed', 'spring', 'summer', 'winter', 'Monday', 'Saturday', 'Tuesday', 'Light Snow/Rain', 'Mist and Cloudy']

build_regressor(X_train,y_train,top_14)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.824
# Model:                            OLS   Adj. R-squared:                  0.819
# Method:                 Least Squares   F-statistic:                     161.4
# Date:                Mon, 28 Dec 2020   Prob (F-statistic):          4.18e-172
# Time:                        19:33:44   Log-Likelihood:                -4045.0
# No. Observations:                 499   AIC:                             8120.
# Df Residuals:                     484   BIC:                             8183.
# Df Model:                          14
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            3032.8337    357.637      8.480      0.000    2330.120    3735.547
# yr               1982.8192     74.162     26.736      0.000    1837.101    2128.538
# holiday          -654.3364    246.271     -2.657      0.008   -1138.229    -170.444
# workingday         15.0923    113.548      0.133      0.894    -208.016     238.201
# temp             3680.7017    310.672     11.848      0.000    3070.270    4291.134
# hum             -1306.9414    346.614     -3.771      0.000   -1987.996    -625.887
# windspeed        -989.7456    205.918     -4.807      0.000   -1394.348    -585.143
# spring           -966.4047    191.189     -5.055      0.000   -1342.067    -590.742
# summer            317.4498    120.766      2.629      0.009      80.160     554.740
# winter            662.4701    152.002      4.358      0.000     363.804     961.136
# Monday           -273.0507    112.060     -2.437      0.015    -493.235     -52.867
# Saturday           11.1378    134.049      0.083      0.934    -252.252     274.528
# Tuesday          -245.2348    111.820     -2.193      0.029    -464.947     -25.523
# Light Snow/Rain -1977.7990    239.641     -8.253      0.000   -2448.665   -1506.933
# Mist and Cloudy  -452.7424     98.493     -4.597      0.000    -646.269    -259.216
# ==============================================================================
# Omnibus:                       73.201   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              140.842
# Skew:                          -0.840   Prob(JB):                     2.61e-31
# Kurtosis:                       4.988   Cond. No.                         24.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# =======================================================================================================
#            Features  Variance Inflation Factor
# 0             const                      96.20
# 7            spring                       5.02
# 4              temp                       3.81
# 9            winter                       3.23
# 3        workingday                       2.11
# 8            summer                       2.06
# 5               hum                       1.90
# 11         Saturday                       1.78
# 14  Mist and Cloudy                       1.64
# 13  Light Snow/Rain                       1.34
# 6         windspeed                       1.23
# 10           Monday                       1.17
# 2           holiday                       1.16
# 12          Tuesday                       1.16
# 1                yr                       1.03

# %% [markdown]
# **Comment:**
# - Removing Sunday did not impact adjusted R-sqaured
# - We will remove 'Saturday' (Highest p-value in the latest model)

# %%
top_13 = ['yr', 'holiday', 'workingday', 'temp', 'hum', 'windspeed', 'spring', 'summer', 'winter', 'Monday',  'Light Snow/Rain','Tuesday', 'Mist and Cloudy']

build_regressor(X_train,y_train,top_13)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.824
# Model:                            OLS   Adj. R-squared:                  0.819
# Method:                 Least Squares   F-statistic:                     174.2
# Date:                Mon, 28 Dec 2020   Prob (F-statistic):          3.12e-173
# Time:                        19:33:44   Log-Likelihood:                -4045.1
# No. Observations:                 499   AIC:                             8118.
# Df Residuals:                     485   BIC:                             8177.
# Df Model:                          13
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            3039.9406    346.902      8.763      0.000    2358.323    3721.558
# yr               1982.8472     74.085     26.765      0.000    1837.280    2128.414
# holiday          -659.2376    238.857     -2.760      0.006   -1128.560    -189.915
# workingday          9.2667     89.224      0.104      0.917    -166.047     184.581
# temp             3681.1936    310.297     11.863      0.000    3071.501    4290.886
# hum             -1309.2322    345.162     -3.793      0.000   -1987.430    -631.035
# windspeed        -990.7228    205.371     -4.824      0.000   -1394.249    -587.196
# spring           -966.1450    190.967     -5.059      0.000   -1341.371    -590.920
# summer            317.8361    120.553      2.636      0.009      80.966     554.706
# winter            662.5903    151.840      4.364      0.000     364.245     960.935
# Monday           -273.0645    111.945     -2.439      0.015    -493.022     -53.107
# Light Snow/Rain -1976.3025    238.719     -8.279      0.000   -2445.353   -1507.252
# Tuesday          -245.2698    111.704     -2.196      0.029    -464.754     -25.786
# Mist and Cloudy  -452.3624     98.286     -4.603      0.000    -645.481    -259.244
# ==============================================================================
# Omnibus:                       73.373   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              141.317
# Skew:                          -0.841   Prob(JB):                     2.06e-31
# Kurtosis:                       4.991   Cond. No.                         23.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# =======================================================================================================
#            Features  Variance Inflation Factor
# 0             const                      90.69
# 7            spring                       5.02
# 4              temp                       3.81
# 9            winter                       3.23
# 8            summer                       2.06
# 5               hum                       1.89
# 13  Mist and Cloudy                       1.64
# 11  Light Snow/Rain                       1.33
# 3        workingday                       1.30
# 6         windspeed                       1.22
# 10           Monday                       1.17
# 12          Tuesday                       1.16
# 2           holiday                       1.09
# 1                yr                       1.03

# %% [markdown]
# **Comment:**
# - Removing 'Sunday','Saturday' did not impact adjusted R-squared
# - We will remove 'workingday' (Highest p-value in the latest model)

# %%
top_12 = ['yr', 'holiday', 'temp', 'hum', 'windspeed', 'spring', 'summer', 'winter', 'Monday',  'Light Snow/Rain','Tuesday', 'Mist and Cloudy']

build_regressor(X_train,y_train,top_12)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.824
# Model:                            OLS   Adj. R-squared:                  0.819
# Method:                 Least Squares   F-statistic:                     189.1
# Date:                Mon, 28 Dec 2020   Prob (F-statistic):          2.23e-174
# Time:                        19:33:44   Log-Likelihood:                -4045.1
# No. Observations:                 499   AIC:                             8116.
# Df Residuals:                     486   BIC:                             8171.
# Df Model:                          12
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            3043.5864    344.770      8.828      0.000    2366.162    3721.011
# yr               1982.9860     73.997     26.798      0.000    1837.592    2128.381
# holiday          -665.4894    230.912     -2.882      0.004   -1119.199    -211.780
# temp             3681.2173    309.981     11.876      0.000    3072.149    4290.286
# hum             -1306.2494    343.615     -3.801      0.000   -1981.404    -631.095
# windspeed        -990.4577    205.146     -4.828      0.000   -1393.540    -587.375
# spring           -966.2356    190.771     -5.065      0.000   -1341.073    -591.398
# summer            317.9997    120.420      2.641      0.009      81.392     554.607
# winter            662.6795    151.683      4.369      0.000     364.645     960.715
# Monday           -269.2211    105.544     -2.551      0.011    -476.600     -61.842
# Light Snow/Rain -1976.9925    238.383     -8.293      0.000   -2445.382   -1508.603
# Tuesday          -241.4946    105.517     -2.289      0.023    -448.821     -34.169
# Mist and Cloudy  -453.5901     97.473     -4.653      0.000    -645.111    -262.070
# ==============================================================================
# Omnibus:                       73.679   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              142.010
# Skew:                          -0.844   Prob(JB):                     1.46e-31
# Kurtosis:                       4.995   Cond. No.                         21.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# =======================================================================================================
#            Features  Variance Inflation Factor
# 0             const                      89.76
# 6            spring                       5.02
# 3              temp                       3.81
# 8            winter                       3.23
# 7            summer                       2.06
# 4               hum                       1.88
# 12  Mist and Cloudy                       1.62
# 10  Light Snow/Rain                       1.33
# 5         windspeed                       1.22
# 9            Monday                       1.04
# 11          Tuesday                       1.04
# 1                yr                       1.03
# 2           holiday                       1.02

# %% [markdown]
# **Comment:**
#
# - Removing 'Sunday','Saturday','workingday' from top 15 features of RFE did not impact adjusted R-squared of model
# - All the features have VIF < 7 now, which ensures there is no collinearity.
# - All the features have p-value < 0.05 (assumed significance level), hence all the features are important.
# - Hence we would build our final model with the following features
# top_12 = ['yr', 'holiday', 'temp', 'hum', 'windspeed', 'spring', 'summer', 'winter', 'Monday',  'Light Snow/Rain','Tuesday', 'Mist and Cloudy']

# %% [markdown]
# ### Final Model

# %%
top_12 = ['yr', 'holiday', 'temp', 'hum', 'windspeed', 'spring', 'summer', 'winter', 'Monday',  'Light Snow/Rain','Tuesday', 'Mist and Cloudy']
X_train_top12 = X_train[top_12]
regressor = LinearRegression()
regressor.fit(X_train_top12, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ### Residual Analysis of Training Data

# %%
y_train_pred = regressor.predict(X_train_top12)

# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((y_train - y_train_pred), bins = 20)
fig.suptitle('Distribution of Error Terms')
plt.xlabel('Errors')
# Out:
# Text(0.5, 0, 'Errors')

# %% [markdown]
# **Comment:**
# Error terms are normally distributed around 0. Hence assumption of linear regression holds true here.

# %% [markdown]
# ### Making Predictions Using the Final Model

# %%
X_test_top12 = X_test[top_12]

y_test_pred = regressor.predict(X_test_top12)

# %%
plt.scatter(y_test, (y_test-y_test_pred))
plt.title("y_test vs. Residual")
plt.show()

# %% [markdown]
# **Comment:**
# - There is no visible pattern in residual with change in y_test. Hence we can assume residual having constant variance/homoscedastic.

# %% [markdown]
# ### Model Evaluation

# %%
# Plotting y_test and y_pred to understand the spread

plt.scatter(y_test, y_test_pred)
plt.title('y_test vs y_test_pred')
plt.xlabel('y_test')
plt.ylabel('y_test_pred')      
plt.show()

# %% [markdown]
# ### MAE, MSE, RMSE

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, y_test_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_test_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
# Out:
# MAE: 590.925147108436
# MSE: 609323.0868991815
# RMSE: 780.591498095631

# %% [markdown]
# ### R2_score

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test, y_test_pred))
# Out:
# 0.8372335856170872

# %% [markdown]
# ### Subjective Question Code

# %%
# Top 3 features with respect to absolute value of coefficient- temp, Light Snow/Rain, year

#(1)temp             3681.2173
#(2) yr              1982.9860
#(3)Light Snow/Rain -1976.9925

# %%
sns.lmplot(x="temp",y="cnt",data=df)
plt.title("Temperature vs. Bike Demand")
plt.show()

# %%
df.groupby("Light Snow/Rain").mean()["cnt"].plot.bar()
plt.ylabel("cnt")
plt.title("Shared Bike Demand(cnt) vs. Light Snow/Rain")
plt.show()

# %%
sns.boxplot(df['yr'], df['cnt'])
plt.title("Year vs. Bike Demand")
plt.show()

# %% [markdown]
# ### Conclusion:

# %% [markdown]
# The expression for Multiple Linear Regression is-
#
# y = a + b1X1 + b2X2 + ... + bnXn
#
# Here, a is the intercept.
#
# b1, b2, ... , bn are the coefficients of the independent variables. bn is the change in y(cnt, here) with unit change in Xn, when rest of the variables are constant.
#
# With respect to the final model,
#
# - number of predictors n = 12
#
# - The independent variables that were used in final model are-
# 'yr', 'holiday', 'temp', 'hum', 'windspeed', 'spring', 'summer', 'winter', 'Monday',  'Light Snow/Rain','Tuesday', 'Mist and Cloudy'
#
# - Among this 3 most important features were - temp, Light Snow/Rain, year
# This was decided by inspecting absolute value of their coefficient. Negative sign is coefficient means the variable is negative correlated with target varible (cnt).
#
# - The model is also validated against serveral assumptions of Linear Regression - linearity, normally distributed error, contant variance of error.
#
# - The model is evaluated by R2_score and RMSE.
# R2_score of 0.8372 means 83.72% of variance in the data is explained by the model.
# RMSE or Root Mean Squarred Error is calculated in the same unit as the target variable. RMSE of 780 means, the prediction made by this model can be over or underestimated by 780 units at maximum.
